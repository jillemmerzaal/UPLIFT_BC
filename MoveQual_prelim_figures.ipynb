# %%
import numpy as np
import pandas as pd
import ptitprince as pt
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import data

# %%
raw_t0 = pd.read_excel('C:/Users/u0117545/Documents/GitHub/ULIFT_BC/MoveQual_aff.xlsx', sheet_name = 'T0')
raw_t1 = pd.read_excel('C:/Users/u0117545/Documents/GitHub/ULIFT_BC/MoveQual_aff.xlsx', sheet_name = 'T1')

raw = pd.concat([raw_t0, raw_t1], axis=0, ignore_index=True)
raw
# Out:
#       ppID    trial time  lyapExp_x  lyapExp_y  lyapExp_z  lyapExp_res  \
# 0   BC_001  F_R_001   T0   2.930375   2.263738   2.430070     5.475767
# 1   BC_002  F_L_001   T0   5.116139   1.995793   1.795426     3.353428
# 2   BC_003  F_R_001   T0   1.218084   1.566631   2.129498     5.326737
# 3   BC_005  F_R_001   T0   3.005529   2.181107   2.893793     2.101779
# 4   BC_006  F_R_001   T0   2.283185   2.426332   2.294448     3.878562
# 5   BC_007  F_R_001   T0   2.753774   1.612023   4.303666     4.303666
# 6   BC_009  F_L_001   T0   2.918751   2.471717   2.810934     2.810934
# 7   BC_010  F_L_001   T0   3.486245   1.548177   2.439655     2.439655
# 8   BC_011  F_L_001   T0   2.905801   2.352076   1.537338     4.397603
# 9   BC_012  F_R_001   T0   2.704405   2.743215   2.781071     2.781071
# 10  BC_014  F_R_001   T0   3.407518   1.224232   2.380618     2.380618
# 11  BC_019  F_R_001   T0   4.545882   1.890196   3.298097     3.298097
# 12  BC_001  F_R_001   T1   7.701734   8.671551   1.385935     5.150145
# 13  BC_002  F_L_001   T1   4.819965   2.955782   4.651802     4.651802
# 14  BC_003  F_R_001   T1   2.935410   1.640538   3.245344     3.245344
# 15  BC_005  F_R_001   T1   3.296498   2.138640   2.523334     4.294144
# 16  BC_006  F_R_001   T1   2.100760   1.943798   2.159363     3.721140
# 17  BC_009  F_L_001   T1   2.694869   2.228210   4.006409     4.006409
# 18  BC_010  F_L_001   T1   4.842058   2.307720   2.108348     3.994292
# 19  BC_011  F_L_001   T1   2.846471   1.701904   2.429810     4.622090
# 20  BC_012  F_R_001   T1   2.789140   1.110174   3.379796     3.379796
# 21  BC_014  F_R_001   T1   1.688677   1.518837   1.657796     3.314314
#
#       LDLJ_A   sparc_x   sparc_y  ...     reg_y     reg_z   reg_res     rms_x  \
# 0  -7.216972 -7.654937 -2.816938  ...  0.259874  0.533197  0.449899  2.762406
# 1  -8.139826 -6.988909 -2.754969  ...  0.812084  0.896444  0.862526  1.820261
# 2  -7.210031 -8.575360 -3.036090  ...  0.438440  0.514514  0.567452  4.230664
# 3  -7.608029 -4.273871 -3.174438  ...  0.473134  0.602492  0.423030  1.667980
# 4  -8.283205 -7.404462 -3.155701  ...  0.568134  0.737490  0.699879  1.839692
# 5  -7.347085 -4.965143 -2.869368  ...  0.403557  0.616868  0.346806  2.131257
# 6  -7.167135 -3.993691 -2.928549  ...  0.875346  0.936337  0.900233  1.908666
#
# [22 rows x 29 columns]

# %% [markdown]
# ### create datafram with index

# %%
df = raw.iloc[0:,1:]
df.index = raw.iloc[0:,0]
df.head()
# Out:
#           trial time  lyapExp_x  lyapExp_y  lyapExp_z  lyapExp_res    LDLJ_A  \
# ppID
# BC_001  F_R_001   T0   2.930375   2.263738   2.430070     5.475767 -7.216972
# BC_002  F_L_001   T0   5.116139   1.995793   1.795426     3.353428 -8.139826
# BC_003  F_R_001   T0   1.218084   1.566631   2.129498     5.326737 -7.210031
# BC_005  F_R_001   T0   3.005529   2.181107   2.893793     2.101779 -7.608029
# BC_006  F_R_001   T0   2.283185   2.426332   2.294448     3.878562 -8.283205
#
#          sparc_x   sparc_y   sparc_z  ...     reg_y     reg_z   reg_res  \
# ppID                                  ...
# BC_001 -7.654937 -2.816938 -3.854986  ...  0.259874  0.533197  0.449899
# BC_002 -6.988909 -2.754969 -3.667989  ...  0.812084  0.896444  0.862526
# BC_003 -8.575360 -3.036090 -4.427668  ...  0.438440  0.514514  0.567452
# BC_005 -4.273871 -3.174438 -4.746577  ...  0.473134  0.602492  0.423030
# BC_006 -7.404462 -3.155701 -4.634375  ...  0.568134  0.737490  0.699879
#
#            rms_x     rms_y     rms_z   rms_res    rmsr_x    rmsr_y    rmsr_z
# ppID
# BC_001  2.762406  0.730227  3.546647  4.554429  0.606532  0.160333  0.778725
# BC_002  1.820261  1.318320  2.329474  3.236938  0.562340  0.407274  0.719654
# BC_003  4.230664  1.089191  5.488949  7.015227  0.603069  0.155261  0.782434
# BC_005  1.667980  1.349332  3.074835  3.749329  0.444874  0.359886  0.820103
# BC_006  1.839692  1.053135  3.219011  3.854295  0.477309  0.273237  0.835175
#
# [5 rows x 28 columns]

# %% [markdown]
# f, ax = plt.subplots(nrows = 5, ncols = 4, sharex = False, sharey = False, figsize = (20,20));
#
# dx = "time"; ort = "v"; pal = 'colorblind'; sigma = .6; viol = .6; mv = .2
#
# sns.despine(offset=10)
# f.tight_layout();
# offset = 0.1;
#
# cols = ['X', 'Y', 'Z', 'RES']
# rows = ['LyE S', 'LyE L', 'SPARC', 'SampEn', 'LDLJ']
# pad = 5
# for axes, row in zip(ax[:,0], rows):
#     axes.annotate(row,xy=(0, 0.5), xytext=(-axes.yaxis.labelpad-pad,0),
#                 xycoords=axes.yaxis.label, textcoords='offset points',
#                 size='large', ha='right', va='center')
#
# for axes, col in zip(ax[0], cols):
#     axes.annotate(col, xy=(0.5, 1), xytext=(0, pad),
#                 xycoords='axes fraction', textcoords='offset points',
#                 size='large', ha='center', va='baseline')
#
#
#
# ## Divergence exponent small
# pt.RainCloud(x = dx, y = "LyEs_x", data = df, palette = pal, bw = sigma,
#                  width_viol = viol, ax = ax[0,0], orient = ort, move = mv)
# ax[0,0].set_xlabel(''); ax[0,0].set_ylabel('');
#
#
# pt.RainCloud(x = dx, y = "LyEs_y", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[0,1], orient = ort, move = mv)
# ax[0,1].set_xlabel(''); ax[0,1].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "LyEs_z", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[0,2], orient = ort, move = mv)
# ax[0,2].set_xlabel(''); ax[0,2].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "LyEs_res", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[0,3], orient = ort, move = mv)
# ax[0,3].set_xlabel(''); ax[0,3].set_ylabel('')
#
# ## Divergence exponent large
# pt.RainCloud(x = dx, y = "LyEl_x", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[1,0], orient = ort, move = mv)
# ax[1,0].set_xlabel(''); ax[1,0].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "LyEl_y", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[1,1], orient = ort, move = mv)
# ax[1,1].set_xlabel(''); ax[1,1].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "LyEl_z", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[1,2], orient = ort, move = mv)
# ax[1,2].set_xlabel(''); ax[1,2].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "LyEl_res", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[1,3], orient = ort, move = mv)
# ax[1,3].set_xlabel(''); ax[1,3].set_ylabel('')
#
# ## SPARC
# pt.RainCloud(x = dx, y = "sparc_x", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[2,0], orient = ort, move = mv)
# ax[2,0].set_xlabel(''); ax[2,0].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "sparc_y", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[2,1], orient = ort, move = mv)
# ax[2,1].set_xlabel(''); ax[2,1].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "sparc_z", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[2,2], orient = ort, move = mv)
# ax[2,2].set_xlabel(''); ax[2,2].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "sparc_res", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[2,3], orient = ort, move = mv)
# ax[2,3].set_xlabel(''); ax[2,3].set_ylabel('')
#
# ## Sample Entropy
# pt.RainCloud(x = dx, y = "SampleEntropy_x", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[3,0], orient = ort, move = mv)
# ax[3,0].set_xlabel(''); ax[3,0].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "SampleEntropy_y", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[3,1], orient = ort, move = mv)
# ax[3,1].set_xlabel(''); ax[3,1].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "SampleEntropy_z", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[3,2], orient = ort, move = mv)
# ax[3,2].set_xlabel(''); ax[3,2].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "SampleEntropy_res", data = df, palette = pal, bw = sigma,
#             width_viol = viol, ax = ax[3,3], orient = ort, move = mv)
# ax[3,3].set_xlabel(''); ax[3,3].set_ylabel('')
#
# pt.RainCloud(x = dx, y = "LDLJ_A", data = df, palette = pal, bw = sigma,
#              width_viol = viol, ax = ax[4,3], orient = ort, move = mv)
# ax[4,3].set_xlabel(''); ax[4,3].set_ylabel('')
#
# f.delaxes(ax = ax[4,1])
# f.delaxes(ax = ax[4,2])
# f.delaxes(ax = ax[4,0])

# %%
X = df.drop(['trial','time'], axis = 1)
# find minimium required rows given we want 5 columns
ncols = 5
nrows = len(X.columns) // ncols + (len(X.columns) % ncols > 0)
dx = "time"; ort = "v"; pal = 'colorblind'; sigma = .6; viol = .6; mv = .0

f = plt.figure(figsize=(20, 20))
plt.subplots_adjust(hspace=0.5)
plt.suptitle("Movement quality for UL", fontsize=18, y=0.95)

f.tight_layout();
offset = 0.1;

for n, columns in enumerate(X.columns):
    # add a new subplot iteratively
    ax = plt.subplot(nrows, ncols, n + 1)
    
    # filter df and plot ticker on the new subplot axis
    #df[df["ticker"] == ticker].plot(ax=ax)
     
    pt.RainCloud(x = dx, y = columns, data = df, ax = ax,
                palette = pal, bw = sigma, width_viol = viol,
                orient = ort, move = mv)
    sns.despine(offset=10)
