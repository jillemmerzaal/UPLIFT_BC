# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/u0117545/Documents\GitHub/ULIFT_BC/EventDetection.csv")
df.head()
# Out:
#    Position Z  Diff Angular Vel Vec     Acc X
# 0    1.484026             -0.005106 -0.207543
# 1    1.484451             -0.003801 -0.182234
# 2    1.484861             -0.002469 -0.155878
# 3    1.485244             -0.001387 -0.128740
# 4    1.485592             -0.000713 -0.101138

# %%
fig, ax = plt.subplots(nrows=3, ncols=1)

sns.lineplot(x=df.index, y='Position Z', data=df, ax=ax[0])
sns.lineplot(x=df.index, y='Diff Angular Vel Vec', data=df, ax=ax[1])
sns.lineplot(x=df.index, y='Acc X', data=df, ax=ax[2])
# Out:
# <AxesSubplot:ylabel='Acc X'>
